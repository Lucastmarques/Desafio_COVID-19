# %% [markdown]
# # Importação dos dados

# %%
import pandas as pd

# %%
atlas_mun = pd.read_csv("AtlasBrasil_IndicadoresSociais.csv", sep=";")
painel_covid = pd.read_csv("HIST_PAINEL_COVIDBR_18mai2020.csv", sep=";")
data_inloco = pd.read_csv("inloco_mun_1705.csv", sep=";")

# %% [markdown]
# ## Dados Atlas Municipios

# %%
atlas_mun.head()
# Out:
#     Código  ... % de extremamente pobres 2010
# 0       76  ...                          6,62
# 1  2400109  ...                          5,18
# 2  2400208  ...                          7,68
# 3  2400307  ...                         21,79
# 4  2400406  ...                         17,77
#
# [5 rows x 8 columns]

# %%
atlas_mun.describe()
# Out:
#              Código
# count  1.680000e+02
# mean   2.393316e+06
# std    1.858000e+05
# min    7.600000e+01
# 25%    2.403744e+06
# 50%    2.407554e+06
# 75%    2.411447e+06
# max    2.415008e+06

# %% [markdown]
# ## Dados Painel Covid

# %%
painel_covid.head()
# Out:
#    regiao estado  ... Recuperadosnovos  emAcompanhamentoNovos
# 0  Brasil    NaN  ...              NaN                    NaN
# 1  Brasil    NaN  ...              NaN                    NaN
# 2  Brasil    NaN  ...              NaN                    NaN
# 3  Brasil    NaN  ...              NaN                    NaN
# 4  Brasil    NaN  ...              NaN                    NaN
#
# [5 rows x 14 columns]

# %%
painel_covid.describe()
# Out:
#               coduf         codmun  ...  Recuperadosnovos  emAcompanhamentoNovos
# count  88948.000000   87077.000000  ...         30.000000              30.000000
# mean      31.402066  315353.181839  ...      50573.233333           61677.866667
# std        9.787037   96533.134654  ...      23714.061350           38135.570372
# min       11.000000  110000.000000  ...      22130.000000           14062.000000
# 25%       24.000000  241150.000000  ...      30399.500000           28352.250000
# 50%       31.000000  314800.000000  ...      44088.500000           53202.000000
# 75%       41.000000  410230.000000  ...      66777.250000           88726.500000
# max       76.000000  530010.000000  ...     100459.000000          136969.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ## Dados InLoco

# %%
data_inloco.head()
# Out:
#    City Name          Dt Isolated_city
# 0  Vila Flor  17/05/2020        41,40%
# 1  Vila Flor  16/05/2020        36,40%
# 2  Vila Flor  15/05/2020        47,90%
# 3  Vila Flor  14/05/2020        44,00%
# 4  Vila Flor  13/05/2020        41,90%

# %%
data_inloco.describe()
# Out:
#         City Name          Dt Isolated_city
# count         107         107           107
# unique          1         107            93
# top     Vila Flor  07/05/2020        37,20%
# freq          107           1             3

# %% [markdown]
# # Limpeza dos dados

# %%
atlas_mun_rn = atlas_mun.drop(atlas_mun.index[0])
# Out:
#       Código  ... % de extremamente pobres 2010
# 1    2400109  ...                          5,18
# 2    2400208  ...                          7,68
# 3    2400307  ...                         21,79
# 4    2400406  ...                         17,77
# 5    2400505  ...                         21,46
# ..       ...  ...                           ...
# 163  2414704  ...                         12,47
# 164  2414753  ...                         33,73
# 165  2414803  ...                         12,44
# 166  2414902  ...                            19
# 167  2415008  ...                         12,72
#
# [167 rows x 8 columns]

# %%
painel_covid_rn = painel_covid[painel_covid.estado == "RN"]
painel_covid_rn = painel_covid_rn[pd.notna(painel_covid_rn.municipio)]

painel_covid_rn
# Out:
#          regiao estado  ... Recuperadosnovos  emAcompanhamentoNovos
# 21472  Nordeste     RN  ...              NaN                    NaN
# 21473  Nordeste     RN  ...              NaN                    NaN
# 21474  Nordeste     RN  ...              NaN                    NaN
# 21475  Nordeste     RN  ...              NaN                    NaN
# 21476  Nordeste     RN  ...              NaN                    NaN
# ...         ...    ...  ...              ...                    ...
# 24232  Nordeste     RN  ...              NaN                    NaN
# 24233  Nordeste     RN  ...              NaN                    NaN
# 24234  Nordeste     RN  ...              NaN                    NaN
# 24235  Nordeste     RN  ...              NaN                    NaN
# 24236  Nordeste     RN  ...              NaN                    NaN
#
# [2765 rows x 14 columns]
