# %% [markdown]
# #Análise dos dados

# %%
import pandas as pd

# %%
dist_soc_inloco = pd.read_csv("Natal_inloco_14a1805.csv", sep=";")

dist_soc_inloco
# Out:
#        Dia de Dt  Point Order  ...           Lat           Lng
# 0     14/05/2020            1  ...  -5,731447937  -35,25814635
# 1     14/05/2020            2  ...  -5,728057668  -35,25417075
# 2     14/05/2020            3  ...  -5,722920611  -35,25510569
# 3     14/05/2020            4  ...  -5,721173724  -35,26001621
# 4     14/05/2020            5  ...  -5,724563953  -35,26399189
# ...          ...          ...  ...           ...           ...
# 4165  18/05/2020            2  ...  -5,840862807   -35,2611962
# 4166  18/05/2020            3  ...  -5,835726311  -35,26213126
# 4167  18/05/2020            4  ...  -5,833980622  -35,26704268
# 4168  18/05/2020            5  ...  -5,837371488  -35,27101913
# 4169  18/05/2020            6  ...  -5,842508082   -35,2700841
#
# [4170 rows x 9 columns]
